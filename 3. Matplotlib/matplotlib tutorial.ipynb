# %% [markdown]
# ## Matplotlib

# %% [markdown]
# ### Line plot

# %% [markdown]
# #### Syntax

# %% [markdown]
# <span class="mark">plt.plot(*args, scalex=True, scaley=True, data=None, **kwargs)</span>
#
#  plot(x, y)        # plot x and y using default line style and color
#
#  plot(x, y, 'bo')  # plot x and y using blue circle markers
#
#  plot(y)           # plot y using x as index array 0..N-1
#
#  plot(y, 'r+')     # ditto, but with red plusses

# %%
from matplotlib import pyplot as plt

lst1 = [1,2,3,4,5,6]
lst2 = [7,2,5,6,7,8]

# %% [markdown]
# <font color = 'red'><b>Line plot

# %%
plt.plot(lst1,lst2)
plt.show()

# %% [markdown]
# #### plotting a line plot curve between x and x^2

# %%
lst1 = [i for i in range(1,10)]

lst2 = [i**2 for i in range (1,10)]

plt.plot(lst1,lst2)
plt.show()

# %% [markdown]
# #### label in line plot

# %% [markdown]
# <font color = 'red'><b>giving a label in the line graph

# %%
 ''' plt.legend() once you provide the label to view thw same'''
# Out:
# ' plt.legend() once you provide the label'

# %%
age = [19,18,15,23,24]
sugar = [23,20,30,33,35]

plt.plot(age,sugar,label= 'sugar graph')
plt.legend()
plt.show()

# %% [markdown]
# #### Providing a marker and colour

# %%
#age vs sugar plot,marker o shaped,color = red 

age = [19,18,15,23,24]
sugar = [23,20,30,33,35]

plt.plot(age,sugar,marker='o',color='r',label='sugar graph')
plt.legend()
plt.show()

# %% [markdown]
# #### line width in line plot

# %%
#age vs sugar plot, linewidth=5

age = [19,18,15,23,24]
sugar = [23,20,30,33,35]

plt.plot(age,sugar,marker='o',color='r',label='sugar graph',linewidth=5)
plt.legend()
plt.show()

# %% [markdown]
# #### label position in line plot

# %% [markdown]
# plt.legend()

# %%
#label position provided by plt.legend(loc='')

# %% [markdown]
# ##### label position 'best' for graph between age and sugar

# %%
age = [19,18,15,23,24]
sugar = [23,20,30,33,35]

plt.plot(age,sugar,marker='o',color='r',label='sugar graph')
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# ##### label position lower right for graph between age and sugar

# %%
plt.plot(age,sugar,marker='o',color='r',label='sugar graph')
plt.legend(loc = 'lower right')
plt.show()

# %% [markdown]
# #### grid in line plot

# %% [markdown]
# plt.grid(visible=None, which='major', axis='both', **kwargs)

# %% [markdown]
# ##### grid in a line plot between age and sugar

# %%
age = [19,18,15,23,24]
sugar = [23,20,30,33,35]

plt.plot(age,sugar,marker='o',color='r',label='sugar graph')
plt.legend(loc = 'lower right')
plt.grid()
plt.show()

# %% [markdown]
# ##### grid colour

# %%
age = [19,18,15,23,24]
sugar = [23,20,30,33,35]

plt.plot(age,sugar,marker='o',color='r',label='sugar graph')
plt.legend(loc = 'best')
plt.grid(color='yellow')
plt.show()

# %% [markdown]
# #### Line plot title

# %% [markdown]
#  <span class="mark">plt.title(label, fontdict=None, loc=None, pad=None, *, y=None, **kwargs)</span>

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ##### plot bewtween sugar and age with title

# %%
age = [19,18,15,23,24]
sugar = [23,20,30,33,35]

plt.plot(age,sugar,marker='o',color='r',label='sugar graph')
plt.title('Sugar Graph')
plt.legend(loc = 'best')
plt.grid(color='yellow')
plt.show()

# %% [markdown]
# #### Line style

# %%
#plot line style of -- between sugar and age

age = [19,18,15,23,24]
sugar = [23,20,30,33,35]

plt.plot(age,sugar,marker='^',color='r',label='sugar graph',ls='--',linewidth=2)
plt.title('Sugar Graph')
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# #### Labeling of x and y axis

# %% [markdown]
# <span class="mark">plt.xlabel(xlabel, fontdict=None, labelpad=None, *, loc=None, **kwargs</span>)

# %% [markdown]
# <span class="mark">plt.ylabel(ylabel, fontdict=None, labelpad=None, *, loc=None, **kwargs)</span>

# %%
age = [19,18,15,23,24]
sugar = [23,20,30,33,35]

plt.plot(age,sugar,marker='o',color='r',label='sugar graph',ls='--',linewidth=2)
plt.title('Sugar Graph')
plt.xlabel('age')
plt.ylabel('sugar')
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# #### Plotting a sine curve

# %% [markdown]
# ##### plotting a sine curve using numpy and matplotlib

# %%
import numpy as np
df = np.arange(0,np.pi*2,0.4)
df = np.sin(df)
print(df)

plt.plot(df,marker='o',color='r',label='Graph')
plt.xlabel('Pi values in rad')
plt.ylabel('sine vaues -1 to 1')
plt.legend(loc='best')
plt.show()
# Out:
# [ 0.          0.38941834  0.71735609  0.93203909  0.9995736   0.90929743
#   0.67546318  0.33498815 -0.05837414 -0.44252044 -0.7568025  -0.95160207
#  -0.99616461 -0.88345466 -0.63126664 -0.2794155 ]

# %%
#cos curve

import numpy as np
b = np.arange(0,np.pi*3,0.2)
b = np.cos(b)
b
plt.plot(b,label='cosine graph',marker='o',color='green')
plt.title('Cos Graph')
plt.xlabel('pi values')
plt.ylabel('cos values from -1 to 1')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Bar graph

# %% [markdown]
# ##### Note:

# %% [markdown]
# <span class="mark">plt.bar(x,height,width=0.8,bottom=None,*,align='center',data=None,**kwargs,)</span>

# %% [markdown]
# Parameters
#
# x : float or array-like
#     The x coordinates of the bars. See also *align* for the
#     alignment of the bars to the coordinates.
#
# height : float or array-like
#     The height(s) of the bars.
#
# width : float or array-like, default: 0.8
#     The width(s) of the bars.
#
# bottom : float or array-like, default: 0
#     The y coordinate(s) of the bars bases.
#
# align : {'center', 'edge'}, default: 'center'
#     Alignment of the bars to the *x* coordinates:
#
#     - 'center': Center the base on the *x* positions.
#     - 'edge': Align the left edges of the bars with the *x* positions.
#
#     To align the bars on the right edge pass a negative *width* and
#     ``align='edge'``.

# %% [markdown]
# Other Parameters
#
# color : color or list of color, optional
#     The colors of the bar faces.
#
# edgecolor : color or list of color, optional
#     The colors of the bar edges.
#
# linewidth : float or array-like, optional
#     Width of the bar edge(s). If 0, don't draw edges.
#
# tick_label : str or list of str, optional
#     The tick labels of the bars.
#     Default: None (Use default numeric labels.)

# %% [markdown]
# ##### plotting a bar graph between x and x^2

# %%
lst1 = [i for i in range(1,10)]
lst2 = [i**2 for i in range (1,10)]

plt.bar(lst1,lst2)
plt.show()

# %% [markdown]
# #### for drawing horizontal bar diagram

# %% [markdown]
# <div class="mark">
# plt.barh(y, width, height=0.8, left=None, *, align='center', **kwargs)</div><i class="fa fa-lightbulb-o "></i>

# %% [markdown]
# ##### plotting a horizontal bar graph between x and x^2

# %%
lst1 = [i for i in range(1,10)]
lst2 = [i**2 for i in range (1,10)]

plt.barh(lst1,lst2)
plt.show()

# %% [markdown]
# #### Bar graph with xticks and y ticks

# %% [markdown]
# ##### xticks

# %% [markdown]
# <span class="mark">plt.xticks(ticks=None, labels=None, **kwargs)</span>

# %% [markdown]
# ###### ploting name of company and its revenue and profit

# %%
company = ['Google','Amazon',"flipkart",'Oneweb']  #number of var is list must be equal
revenue = [90,86,54,63]
profit = [40,33,21,26]

xpos = np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.xticks(xpos,company)     #the first arg of xticks is an array,second what needed tobe filled
plt.bar(xpos-0.2,revenue,width=0.4)   # =0.2 to left and +0.2 to right with width=4 to com rev and prof.
plt.bar(xpos+0.2,profit,width=0.4)
plt.show()

# %% [markdown]
# ###### bar graph without  specifing position from the centre

# %%
plt.xticks(xpos,company)
plt.bar(xpos,revenue,width=0.4,label='revenue')
plt.bar(xpos,profit,width=0.4,label='profit')
plt.legend()
plt.show()

# %% [markdown]
# ##### yticks

# %% [markdown]
# <div class="mark">
# plt.yticks(ticks=None, labels=None, **kwargs)</div><i class="fa fa-lightbulb-o "></i>

# %%
# yticks basically used  to give user specified index in y axis

#horizontal bar graph

# %% [markdown]
# ###### plotting a Bar graph comparission between companies and its revenue and profit

# %%
company = ['Google','Amazon',"flipkart",'Oneweb']  
revenue = [90,86,54,63]
profit = [40,33,21,26]
xpos = np.arange(len(company))
xpos

plt.yticks(xpos,company)
plt.barh(xpos,revenue,label='revenue')
plt.barh(xpos,profit,label='profit')
plt.legend()
plt.show()

# %% [markdown]
# ### Histogram plot

# %% [markdown]
# #### syntax

# %% [markdown]
# plt.hist(x,bins=None,range=None,density=False,
# weights=None,cumulative=False,bottom=None,
# histtype='bar',align='mid',orientation='vertical',
# rwidth=None, log=False,color=None,label=None,stacked=False,*,data=None,**kwargs,)

# %% [markdown]
# ###### notes

# %% [markdown]
# Parameters
#
# x : (n,) array or sequence of (n,) arrays
#     Input values, this takes either a single array or a sequence of
#     arrays which are not required to be of the same length.
#
# bins : int or sequence or str, default: :rc:`hist.bins`
#     If *bins* is an integer, it defines the number of equal-width bins
#     in the range.
#
#     If *bins* is a sequence, it defines the bin edges, including the
#     left edge of the first bin and the right edge of the last bin;
#     in this case, bins may be unequally spaced.  All but the last
#     (righthand-most) bin is half-open.  In other words, if *bins* is::
#
#         [1, 2, 3, 4]
#
#     then the first bin is ``[1, 2)`` (including 1, but excluding 2) and
#     the second ``[2, 3)``.  The last bin, however, is ``[3, 4]``, which
#     *includes* 4.
#
#     If *bins* is a string, it is one of the binning strategies
#     supported by `numpy.histogram_bin_edges`: 'auto', 'fd', 'doane',
#     'scott', 'stone', 'rice', 'sturges', or 'sqrt'.
#
# range : tuple or None, default: None
#     The lower and upper range of the bins. Lower and upper outliers
#     are ignored. If not provided, *range* is ``(x.min(), x.max())``.
#     Range has no effect if *bins* is a sequence.
#
#     If *bins* is a sequence or *range* is specified, autoscaling
#     is based on the specified bin range instead of the
#     range of x.
#
# density : bool, default: False
#     If ``True``, draw and return a probability density: each bin
#     will display the bin's raw count divided by the total number of
#     counts *and the bin width*
#     (``density = counts / (sum(counts) * np.diff(bins))``),
#     so that the area under the histogram integrates to 1
#     (``np.sum(density * np.diff(bins)) == 1``).
#
#     If *stacked* is also ``True``, the sum of the histograms is
#     normalized to 1.
#
# weights : (n,) array-like or None, default: None
#     An array of weights, of the same shape as *x*.  Each value in
#     *x* only contributes its associated weight towards the bin count
#     (instead of 1).  If *density* is ``True``, the weights are
#     normalized, so that the integral of the density over the range
#     remains 1.
#
#     This parameter can be used to draw a histogram of data that has
#     already been binned, e.g. using `numpy.histogram` (by treating each
#     bin as a single point with a weight equal to its count) ::
#
#         counts, bins = np.histogram(data)
#         plt.hist(bins[:-1], bins, weights=counts)
#
#     (or you may alternatively use `~.bar()`).
#
# cumulative : bool or -1, default: False
#     If ``True``, then a histogram is computed where each bin gives the
#     counts in that bin plus all bins for smaller values. The last bin
#     gives the total number of datapoints.
#
#     If *density* is also ``True`` then the histogram is normalized such
#     that the last bin equals 1.
#
#     If *cumulative* is a number less than 0 (e.g., -1), the direction
#     of accumulation is reversed.  In this case, if *density* is also
#     ``True``, then the histogram is normalized such that the first bin
#     equals 1.
#
# bottom : array-like, scalar, or None, default: None
#     Location of the bottom of each bin, ie. bins are drawn from
#     ``bottom`` to ``bottom + hist(x, bins)`` If a scalar, the bottom
#     of each bin is shifted by the same amount. If an array, each bin
#     is shifted independently and the length of bottom must match the
#     number of bins. If None, defaults to 0.
#
# histtype : {'bar', 'barstacked', 'step', 'stepfilled'}, default: 'bar'
#     The type of histogram to draw.
#
#     - 'bar' is a traditional bar-type histogram.  If multiple data
#       are given the bars are arranged side by side.
#     - 'barstacked' is a bar-type histogram where multiple
#       data are stacked on top of each other.
#     - 'step' generates a lineplot that is by default unfilled.
#     - 'stepfilled' generates a lineplot that is by default filled.
#
# align : {'left', 'mid', 'right'}, default: 'mid'
#     The horizontal alignment of the histogram bars.
#
#     - 'left': bars are centered on the left bin edges.
#     - 'mid': bars are centered between the bin edges.
#     - 'right': bars are centered on the right bin edges.
#
# orientation : {'vertical', 'horizontal'}, default: 'vertical'
#     If 'horizontal', `~.Axes.barh` will be used for bar-type histograms
#     and the *bottom* kwarg will be the left edges.
#
# rwidth : float or None, default: None
#     The relative width of the bars as a fraction of the bin width.  If
#     ``None``, automatically compute the width.
#
#     Ignored if *histtype* is 'step' or 'stepfilled'.
#
# log : bool, default: False
#     If ``True``, the histogram axis will be set to a log scale.
#
# color : color or array-like of colors or None, default: None
#     Color or sequence of colors, one per dataset.  Default (``None``)
#     uses the standard line color sequence.
#
# label : str or None, default: None
#     String, or sequence of strings to match multiple datasets.  Bar
#     charts yield multiple patches per dataset, but only the first gets
#     the label, so that `~.Axes.legend` will work as expected.
#
# stacked : bool, default: False
#     If ``True``, multiple data are stacked on top of each other If
#     ``False`` multiple data are arranged side by side if histtype is
#     'bar' or on top of each other if histtype is 'step'

# %% [markdown]
# #### plotting a histogram for lst2 x^2

# %%
lst1 = [i for i in range(1,10)]
lst2 = [i**2 for i in range (1,10)]

plt.hist(lst2,bins=4,rwidth=0.5)
plt.show()

# %% [markdown]
# #### plotting a histogram to visualize age group between specifies range

# %%
age = [12,13,16,25,23,28,26,24,31,35,38,34,8,14,40]

from matplotlib import pyplot as plt
plt.hist(age,bins=[0,10,20,30,40],rwidth=0.5,color=['magenta'])
plt.show()

# %%
# The second graph used is to see difference

from matplotlib import pyplot as plt
plt.hist(age,bins=[0,10,20,30,40,50],rwidth=0.5,color=['magenta'])
plt.show()

# %% [markdown]
# #### ploting a histogram between age and age1

# %%
import numpy as np

age = np.random.randint(10,high=50,size=10)
age = age.tolist()
age.sort()
print(age)

age1 = np.random.randint(10,high=50,size=10)
age1 = age1.tolist()
age1.sort()
print(age1)

#while providing a list to the bins remember to give an exra element at -1 to get full vis

plt.hist([age,age1],bins=[0,12,20,28,35,43,50],rwidth=0.5,color=['red','yellow'])
plt.show()
# Out:
# [17, 21, 32, 33, 35, 37, 40, 42, 43, 47]
# [10, 14, 25, 26, 29, 30, 36, 37, 38, 38]

# %% [markdown]
# #### plotting a histogram between age,age1,age2

# %%
import numpy as np

age = np.random.randint(10,high=50,size=10)
age = age.tolist()
print(age)

age1 = np.random.randint(10,high=50,size=10)
age1 = age1.tolist()
print(age1)

age2 = np.random.randint(10,high=50,size=10)
age2 = age2.tolist()
print(age2)

#we give the input as list of ages

lab = ['age','age1','age2']

plt.hist([age,age1,age2],bins=[0,10,15,20,25,30,35,40,45,50,55],rwidth=0.5,color=['red','green','yellow'],label=lab)
plt.legend()
import matplotlib
matplotlib.rcParams['figure.figsize']=(20,20)  #to resize the plot 
plt.show()
# Out:
# [39, 15, 15, 33, 28, 26, 47, 28, 24, 31]
# [27, 28, 20, 46, 23, 17, 44, 21, 40, 25]
# [31, 35, 13, 26, 31, 44, 46, 32, 49, 49]

# %% [markdown]
# #### plot histogram horizintaly

# %% [markdown]
# ##### example of plotting a histogram horizontally age,age1,age2

# %%
plt.hist([age,age1,age2],bins=[10,15,20,25,30,35,40,45,50,55],rwidth=0.9,label=['age','age1','age2'],orientation='horizontal',color=['red','green','yellow'])
plt.legend()
import matplotlib
matplotlib.rcParams['figure.figsize']=(10,10)
plt.show()

# %% [markdown]
# ### scatter plot

# %% [markdown]
# #### syntax

# %% [markdown]
# plt.scatter(
#     x,
#     y,
#     s=None,
#     c=None,
#     marker=None,
#     cmap=None,
#     norm=None,
#     vmin=None,
#     vmax=None,
#     alpha=None,
#     linewidths=None,
#     *,
#     edgecolors=None,
#     plotnonfinite=False,
#     data=None,
#     **kwargs,
# )

# %% [markdown]
# ##### notes

# %% [markdown]
# Parameters
# ----------
# x, y : float or array-like, shape (n, )
#     The data positions.
#
# s : float or array-like, shape (n, ), optional
#     The marker size in points**2.
#     Default is ``rcParams['lines.markersize'] ** 2``.
#
# c : array-like or list of colors or color, optional
#     The marker colors. Possible values:
#
#     - A scalar or sequence of n numbers to be mapped to colors using
#       *cmap* and *norm*.
#     - A 2D array in which the rows are RGB or RGBA.
#     - A sequence of colors of length n.
#     - A single color format string.
#
#     Note that *c* should not be a single numeric RGB or RGBA sequence
#     because that is indistinguishable from an array of values to be
#     colormapped. If you want to specify the same RGB or RGBA value for
#     all points, use a 2D array with a single row.  Otherwise, value-
#     matching will have precedence in case of a size matching with *x*
#     and *y*.
#
#     If you wish to specify a single color for all points
#     prefer the *color* keyword argument.
#
#     Defaults to `None`. In that case the marker color is determined
#     by the value of *color*, *facecolor* or *facecolors*. In case
#     those are not specified or `None`, the marker color is determined
#     by the next color of the ``Axes``' current "shape and fill" color
#     cycle. This cycle defaults to :rc:`axes.prop_cycle`.
#
# marker : `~.markers.MarkerStyle`, default: :rc:`scatter.marker`
#     The marker style. *marker* can be either an instance of the class
#     or the text shorthand for a particular marker.
#     See :mod:`matplotlib.markers` for more information about marker
#     styles.
#
# cmap : str or `~matplotlib.colors.Colormap`, default: :rc:`image.cmap`
#     A `.Colormap` instance or registered colormap name. *cmap* is only
#     used if *c* is an array of floats.
#
# norm : `~matplotlib.colors.Normalize`, default: None
#     If *c* is an array of floats, *norm* is used to scale the color
#     data, *c*, in the range 0 to 1, in order to map into the colormap
#     *cmap*.
#     If *None*, use the default `.colors.Normalize`.
#
# vmin, vmax : float, default: None
#     *vmin* and *vmax* are used in conjunction with the default norm to
#     map the color array *c* to the colormap *cmap*. If None, the
#     respective min and max of the color array is used.
#     It is an error to use *vmin*/*vmax* when *norm* is given.
#
# alpha : float, default: None
#     The alpha blending value, between 0 (transparent) and 1 (opaque).
#
# linewidths : float or array-like, default: :rc:`lines.linewidth`
#     The linewidth of the marker edges. Note: The default *edgecolors*
#     is 'face'. You may want to change this as well.
#
# edgecolors : {'face', 'none', *None*} or color or sequence of color, default: :rc:`scatter.edgecolors`
#     The edge color of the marker. Possible values:
#
#     - 'face': The edge color will always be the same as the face color.
#     - 'none': No patch boundary will be drawn.
#     - A color or sequence of colors.
#
#     For non-filled markers, *edgecolors* is ignored. Instead, the color
#     is determined like with 'face', i.e. from *c*, *colors*, or
#     *facecolors*.
#
# plotnonfinite : bool, default: False
#     Whether to plot points with nonfinite *c* (i.e. ``inf``, ``-inf``
#     or ``nan``). If ``True`` the points are drawn with the *bad*
#     colormap color (see `.Colormap.set_bad`)

# %% [markdown]
# #### creating a scatter plot between age and sugar

# %%
age = [19,18,15,23,24]
sugar = [23,20,30,33,35]

plt.scatter(age,sugar)
import matplotlib
matplotlib.rcParams['figure.figsize']=(8,5)
plt.show()

# %% [markdown]
# ### pie chart

# %% [markdown]
# plt.pie(
#     x,
#     explode=None,
#     labels=None,
#     colors=None,
#     autopct=None,
#     pctdistance=0.6,
#     shadow=False,
#     labeldistance=1.1,
#     startangle=0,
#     radius=1,
#     counterclock=True,
#     wedgeprops=None,
#     textprops=None,
#     center=(0, 0),
#     frame=False,
#     rotatelabels=False,
#     *,
#     normalize=True,
#     data=None,
# )

# %% [markdown]
# ##### plotting a simple pie chart

# %%
x=np.array([1,2,3,4,5]) #created an array with numpy
plt.pie(x)
plt.show()

# %% [markdown]
# #### labels at pie chart

# %% [markdown]
# ##### plotting a pie chart of vals and providing exp_lab as label

# %%
vals = [50,15,15,10,5,5]
exp_lab = ['rent','food','phone','dress','luxory','other']

plt.pie(vals,labels=exp_lab,radius=2,shadow=True,startangle=0)
plt.show()

# %% [markdown]
# ##### plotting  pie chart of students Providing the label as Mention below

# %%
students_mark=[23,25,23,34]
labs=['maths','eng','guj','mal']

plt.pie(students_mark,labels=labs,startangle=0,radius=2)
plt.show()

# %% [markdown]
# ### plotting a graph from a dataset

# %% [markdown]
# ##### month number vs total profit curve

# %%
import pandas as pd 

df = pd.read_csv('company_sales_data.csv')
print(df.shape)

print(df.head())

#we first have to convert the series selected into list

profit = df['total_profit'].tolist()

month = df['month_number'].tolist()

plt.plot(month,profit,label='Profit of company',marker='o')
plt.xlabel('month')
plt.ylabel('profit')

plt.xticks(month)  #x axis = month
plt.yticks([100000,200000,300000,400000,500000]) #yaxis =
plt.title('Graph')
plt.legend()
plt.show()
# Out:
# (12, 9)
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %% [markdown]
# ##### plotting from dataset and adding style

# %%
from matplotlib import pyplot as plt
import pandas as pd
df = pd.read_csv('company_sales_data.csv')
print(df.head())

profit = df['total_profit'].tolist()
print(profit,end='')

month = df['month_number'].tolist()
month

plt.plot(month,profit,marker='o',label='month vs profit',markerfacecolor='green',ls='--',lw=3,color='red')
plt.xlabel('month')
plt.ylabel('profit')
plt.title('plot')
plt.xticks(df['month_number'])
plt.yticks([100000,200000,300000,400000,500000])
plt.legend()
plt.show()
#lw - line width
# ls - line style
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600
# [211000, 183300, 224700, 222700, 209600, 201400, 295500, 361400, 234000, 266700, 412800, 300200]

# %% [markdown]
# ##### scatter plot using the dataset

# %%
#scatter plot between month and toothpaste

import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('company_sales_data.csv')
month = df['month_number'].tolist()
toothpaste = df['toothpaste'].tolist()

plt.scatter(month,toothpaste,label='month vs toothpaste',color='red',marker='s')
plt.xlabel('month')
plt.ylabel('toothpaste')
plt.title('plot')
plt.xticks(month)
# plt.yticks(toothpaste)
plt.grid(True,linewidth=1,ls='--') #grid is true as default
plt.legend()
plt.show()
#plt.style.use() is active

# %% [markdown]
# ##### Plotting histogram from dataset

# %%
# histogram plot of profit and profit range
#to know the profit in the mentioned specified range

import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('company_sales_data.csv')
profit=df['total_profit'].tolist()
profit_range=[150000,175000,200000,225000,250000,300000,325000]

plt.hist(profit,profit_range,label=' profit vs profit range',color='red',rwidth=0.5)
plt.grid(ls='--')
plt.xlabel('profit range in dollar')
plt.ylabel('actual profit')
plt.xticks(profit_range)
plt.legend()
plt.title('profit data')
plt.show()

# %% [markdown]
# ### xlim and y lim

# %%
'''It is similar to x ticks and y ticka but the values lie between the range'''

'''example roblem for xlim and ylim'''

# %%
a = [i for i in range(1,10)]
b = [i**2 for i in range(1,10)]
xy=['jan','feb','mar','apr','may','june','july','aug','sep','oct','nov','dec']

import matplotlib.pyplot as plt
plt.plot(a,b,'c+-',mec='r',ms=15,lw=2)
plt.title('x vs x^2')
plt.ylim(0,100)     #here the y axis is divided between range 1-100
# plt.xlim(0,12)
plt.text(x=2,y=20,s='hello')  #to give a text in the specified cordinates
plt.xlabel('numbers')
plt.ylabel('squares')
# plt.legend()
plt.grid(color='g',ls='--')
plt.xticks(range(0,12),xy,rotation=45)
plt.show()

# %% [markdown]
# ### line plot styling elements

# %%
xy=['jan','feb','mar','apr','may','june','july','aug','sep','oct','nov','dec']

import matplotlib.pyplot as plt
import numpy as np
rain1 = np.random.randint(10,high=40,size=12).tolist()
rain2 = np.random.randint(10,high=50,size=12).tolist()
months = np.arange(1,13).tolist()
plt.style.use('dark_background')   #########
plt.plot(months,rain1,'r+-',label='2021',ms=10) #ms-markersize
plt.plot(months,rain2,'go-',label='2022',ms=5,mec='w',mfc='c')
plt.xlabel('months')
plt.ylabel('mm of rain')
plt.xticks(range(1,13),xy,rotation=45)
plt.legend(loc=0,fancybox=True,title='year')  #the box created around label
plt.grid()
plt.show()

#mec = marker edge color
#mfc = marker face color
# ms = marker size

# best = 0

# %%
plt.style.available   # to check different hemes in the plot
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# ### Scatter plot styling

# %%
#creating a scatter plot with #fancy box, #size
import matplotlib.pyplot as plt
import numpy as np
rain1 = np.random.randint(1,high=40,size=12).tolist()
months = np.arange(1,13).tolist()
plt.style.use('classic')
plt.scatter(months,rain1,label='2021',color='red',s=100,marker='^')  #s = size
# plt.scatter(months,rain2)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend(loc=2,fancybox=True,title='year') 
plt.show()
#fancy box used to provide a box around the plot label

# %%
#----------------------------------------------------------

# %% [markdown]
# Adding another element to the scatter plot such that it can be visualized from the size.
# for example in a month vs rain plot  we also want to get an idea about humidity.
# so we assigned humidity to size of the scatter.
# each different sizes represent different humidity condition at that particular instance.

# %%
# random size

xy=['jan','feb','mar','apr','may','june','july','aug','sep','oct','nov','dec']

from matplotlib import pyplot as plt
import numpy as np
rain2 = np.random.randint(1,high=50,size=12).tolist()
month = np.arange(1,13).tolist()
humidity = np.random.randint(200,high=800,size=12).tolist()

plt.scatter(month,rain2,s=humidity,marker='o',color='green',label='Monthly rainfall')
plt.xlabel('Months')
plt.ylabel('Rainfall')
plt.style.use('classic')
plt.xticks(range(1,13),xy,rotation=45)
plt.legend()
plt.grid(True)
plt.title('Different size for scatter')
plt.show()

# %%
#plotting the scatter plot of rain1 and rain2 with rain 1 size=100 and rain 2 size = i**2
import matplotlib.pyplot as plt 
import numpy as np 
rain1=np.random.randint(1,high=25,size=12).tolist()
rain2=np.random.randint(1,high=25,size=12).tolist()
month=np.arange(1,13).tolist()
xy=['jan','feb','mar','apr','may','june','july','aug','sep','oct','nov','dec']

plt.scatter(month,rain1,s=100,label='2021')
plt.scatter(month,rain2,s=[i**2 for i in month],marker='o',color='red',label='2022')
plt.xlabel('Months')
plt.ylabel('Rainfall in cm')
plt.style.use('classic')
plt.xticks(range(1,13),xy,rotation=45)
plt.legend()
plt.grid(True)
plt.title('Different size for scatter')
plt.show()

# %%
# plotting the scatter plot with #alpha(for transparancy)
import matplotlib.pyplot as plt
import numpy as np
N = 50   #50 nos
x = np.random.rand(N) #range between 0-1
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi*(15*np.random.rand(N))**2
plt.scatter(x,y,s=area,c=colors, alpha=0.60)   #aplha = transparancy of plot
plt.style.use('classic')
plt.show()
# print(x)
# print(y)

# %% [markdown]
# ### Other topics

# %% [markdown]
# ##### providing face color and height as y axis to barcart

# %%
#providinf face color and height/y-axis
x = [1,2,3,4,5,6,7]
y = [1.5,2.0,2.5,3.0,3.5,4.0,4.5]
plt.bar(x,height=y,width=0.6,fc='red')  #height to plot the value n y-axis
plt.yticks(y)
plt.grid()
plt.show()

# %% [markdown]
# ##### togive different colours to the bar graph.

# %%
#togive different colours to the bar graph.
# N=50
x = [1,2,3,4,5,6,7]
y = [1.5,2.0,2.5,3.0,3.5,4.0,4.5]
col = ['r','g','c','m','k','orange','b']
# col = np.random.rand(N)
plt.bar(x,height=y,width=0.6,color=col)  #height to plot the value n y-axis
plt.yticks(y)
plt.show()

# %% [markdown]
# ##### to resize a bar graph

# %%
#to resize a bar graph
x = [1,2,3,4,5,6,7]
y = [1.5,2.0,2.5,3.0,3.5,4.0,4.5]
col = ['r','g','c','m','k','orange','b']
plt.figure(figsize=(12,6))  #to change the scale/size of plot
plt.bar(x,height=y,width=0.6,color=col,align='center')  #height to plot the value n y-axis
# plt.yticks(y)
plt.show()
#aligning the location of ticks on x-axis default-true

# %% [markdown]
# ##### same can be done to horizontal plot

# %%
x = [1,2,3,4,5,6,7]
y = [1.5,2.0,2.5,3.0,3.5,4.0,4.5]
col = ['r','g','c','m','k','orange','b']
plt.barh(x,y,color=col)  #height to plot the value n y-axis
plt.show()

# %% [markdown]
# ##### pie plot explode and autopct

# %%
#autopct - used to label percentage inside pie plot
# explode - to distinct a portion from the rest of the chart
vals = [50,15,15,10,5,5]
exp_lab = ['rent','food','phone','dress','luxory','other']
x = (0,0.1,0,0,0.1,0)
plt.pie(vals,labels=exp_lab,radius=1.5,shadow=True,autopct='%1.1f%%',startangle=0,explode=x)
plt.show()
#autopct used to give percentage inside the pie plot

# %% [markdown]
# ##### bbox title box

# %%
#bbox-to provide a box around the title of the plot
import matplotlib.pyplot as plt
vals = [50,15,15,10,5,5]
exp_lab = ['rent','food','phone','dress','luxory','other']
x = (0,0.1,0,0,0.1,0)
plt.pie(vals,labels=exp_lab,radius=1.5,shadow=True,autopct='%1.1f%%',startangle=0,explode=x)
plt.title('hello',bbox=({'facecolor':'red','pad':10})) #do it later
plt.show()
#autopct used to give percentage inside the pie plo

# %% [markdown]
# ### box plot

# %% [markdown]
# ##### plotting of simple box plot

# %%
a = np.arange(1,10)
plt.boxplot(a)
plt.show()

# %% [markdown]
# ##### plotting two box plots

# %%
#create two list
a = np.random.randint(10,high=50,size=7).tolist()
b = np.random.randint(10,high=50,size=7).tolist()

# displays the mean position 
#  pathches the box plot with color
plt.boxplot((a,b),showmeans=True,patch_artist=True)
plt.show()
